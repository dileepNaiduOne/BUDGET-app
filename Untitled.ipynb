# %%
import pandas as pd

# %%
import os

# %%
nn = 0
for root, dirs, files in os.walk(r"C:\Users\DILEEP PATCHA\Desktop\GL PGPDSE\#Projects\neo-bank-non-sub-churn-prediction"):
    for file in files:
        a = os.path.join(root, file)
        if ".parquet" in a:
            print(a)
            n = pd.read_parquet(a)
            print(n.shape)
            nn += n.shape[0]
        else:
            print(False)

nn
# Out:
# False
# False
# False
# False
# False
# False
# C:\Users\DILEEP PATCHA\Desktop\GL PGPDSE\#Projects\neo-bank-non-sub-churn-prediction\test.parquet
# (1360472, 27)
# C:\Users\DILEEP PATCHA\Desktop\GL PGPDSE\#Projects\neo-bank-non-sub-churn-prediction\train_2008.parquet
# (46510, 26)
# C:\Users\DILEEP PATCHA\Desktop\GL PGPDSE\#Projects\neo-bank-non-sub-churn-prediction\train_2009.parquet
# (82852, 26)
# C:\Users\DILEEP PATCHA\Desktop\GL PGPDSE\#Projects\neo-bank-non-sub-churn-prediction\train_2010.parquet
# (129439, 26)
# C:\Users\DILEEP PATCHA\Desktop\GL PGPDSE\#Projects\neo-bank-non-sub-churn-prediction\train_2011.parquet
# (158736, 26)
# C:\Users\DILEEP PATCHA\Desktop\GL PGPDSE\#Projects\neo-bank-non-sub-churn-prediction\train_2012.parquet
# (161235, 26)
# C:\Users\DILEEP PATCHA\Desktop\GL PGPDSE\#Projects\neo-bank-non-sub-churn-prediction\train_2013.parquet
# (188359, 26)
# C:\Users\DILEEP PATCHA\Desktop\GL PGPDSE\#Projects\neo-bank-non-sub-churn-prediction\train_2014.parquet
# ...

# %%
a = pd.read_parquet(r"C:\Users\DILEEP PATCHA\Desktop\GL PGPDSE\#Projects\neo-bank-non-sub-churn-prediction\test.parquet")
a
# Out:
#               Id  customer_id  interest_rate                name  \
# 0        6187320        68714            3.0   Shannon Rodriguez
# 1        6187321        90102            3.0  Michael Hutchinson
# 2        6187322       106090            3.0        Lisa Johnson
# 3        6187323        90092            3.0    Kimberly Bennett
# 4        6187324        90083            3.0    Holly Perkins MD
# ...          ...          ...            ...                 ...
# 1360467  7547787        47228            0.0       Tammy Sanchez
# 1360468  7547788        26232            2.5       Deborah Booth
# 1360469  7547789        39233            2.5         Erin Dudley
# 1360470  7547790        87197            2.5       Tracy Santana
# 1360471  7547791        62157            0.0          Mark Roman
#
#                 country date_of_birth  \
# 0               Belgium    1988-02-03
# 1        Czech Republic    1968-08-01
# 2             Lithuania    1970-04-10
# ...

# %%
a = pd.read_parquet(r"C:\Users\DILEEP PATCHA\Desktop\GL PGPDSE\#Projects\neo-bank-non-sub-churn-prediction\train_2018.parquet")
a.columns
# Out:
# Index(['Id', 'customer_id', 'interest_rate', 'name', 'country',
#        'date_of_birth', 'address', 'date', 'atm_transfer_in',
#        'atm_transfer_out', 'bank_transfer_in', 'bank_transfer_out',
#        'crypto_in', 'crypto_out', 'bank_transfer_in_volume',
#        'bank_transfer_out_volume', 'crypto_in_volume', 'crypto_out_volume',
#        'complaints', 'touchpoints', 'csat_scores', 'tenure', 'from_competitor',
#        'job', 'churn_due_to_fraud', 'model_predicted_fraud'],
#       dtype='object')
